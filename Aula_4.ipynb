# %% [markdown]
# <a href="https://colab.research.google.com/github/Simone-Prado/Aula-Github/blob/main/Aula_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-cfadac0b-4267-4ee4-85af-11b90e2b120a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cfadac0b-4267-4ee4-85af-11b90e2b120a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("clientes_credito_preparacao_ml.csv")


df.head(17)
# Out:
#     id      nome  idade    renda  divida estado_civil aprovado
# 0    1       Ana     25   3200.0    1200     Solteiro      Sim
# 1    2     Bruno     42   8500.0    2500       Casado      Sim
# 2    3     Carla     31      NaN    4200     Solteiro      Não
# 3    4    Daniel     19   1800.0     800     solteiro      Não
# 4    5   Eduarda    150   5000.0    1500       Casado      Sim
# 5    6    Felipe     37   6200.0    2800       CASADO      Sim
# 6    7  Gabriela     29   4100.0    -500     Solteiro      Não
# 7    8  Henrique     48  12000.0    3500   Divorciado      Sim
# 8    9   Isabela     34   7200.0    2100       Casado      Sim
# 9   10      João     23   2600.0    1800     Solteiro      Não
# 10  11     Karen     51  95000.0    4000       Casado      Sim
# 11  12     Lucas     28   3900.0    2400     Solteiro      Não
# 12  13   Mariana     39   9000.0    2700       Casado      Sim
# 13  14   Nicolas     33   5400.0    3100   Divorciado      Não
# ...

# %%
# conhecendo os dados

# quantidade de registros
# tipos das colunas
# valores faltantes
# valores minimos, maximos e categoricos

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            17 non-null     int64
#  1   nome          17 non-null     object
#  2   idade         17 non-null     int64
#  3   renda         16 non-null     float64
#  4   divida        17 non-null     int64
#  5   estado_civil  17 non-null     object
#  6   aprovado      17 non-null     object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 1.1+ KB

# %%
df.describe(include="all")
#unique = nomes diferentes / top maximo(mais vezes) / frequencia / media / minimo / std desvio padrão/ 1, 2 e 3 quartil.
# Out:
#                id      nome       idade         renda       divida  \
# count   17.000000        17   17.000000     16.000000    17.000000
# unique        NaN        16         NaN           NaN          NaN
# top           NaN  Henrique         NaN           NaN          NaN
# freq          NaN         2         NaN           NaN          NaN
# mean     8.470588       NaN   41.647059  11868.750000  2335.294118
# std      4.611367       NaN   29.499875  22418.852743  1195.272551
# min      1.000000       NaN   19.000000   1800.000000  -500.000000
# 25%      5.000000       NaN   28.000000   3725.000000  1800.000000
# 50%      8.000000       NaN   34.000000   5800.000000  2400.000000
# 75%     12.000000       NaN   45.000000   9500.000000  3100.000000
# max     16.000000       NaN  150.000000  95000.000000  4200.000000
#
#        estado_civil aprovado
# count            17       17
# unique            5        2
# top        Solteiro      Sim
# freq              6       10
# ...

# %%
# dados faltantes
df.isnull().sum()
# Out:
# id              0
# nome            0
# idade           0
# renda           1
# divida          0
# estado_civil    0
# aprovado        0
# dtype: int64

# %%
# categorias inconsistentes
# exemplo: Casado, CASADO e casado = são todos a mesma coisa
df["estado_civil"].value_counts()
# Out:
# estado_civil
# Solteiro      6
# Casado        6
# Divorciado    3
# solteiro      1
# CASADO        1
# Name: count, dtype: int64

# %%
# valores suspeitos
df[["idade","renda","divida"]].describe()
# Out:
#             idade         renda       divida
# count   17.000000     16.000000    17.000000
# mean    41.647059  11868.750000  2335.294118
# std     29.499875  22418.852743  1195.272551
# min     19.000000   1800.000000  -500.000000
# 25%     28.000000   3725.000000  1800.000000
# 50%     34.000000   5800.000000  2400.000000
# 75%     45.000000   9500.000000  3100.000000
# max    150.000000  95000.000000  4200.000000

# %%
# fazer uma limpeza simples

# corrigir as categorias lower=coloca as letras em minusculo
df["estado_civil"] = (df["estado_civil"].str.strip().str.lower())

df["estado_civil"].value_counts()
# Out:
# estado_civil
# solteiro      7
# casado        7
# divorciado    3
# Name: count, dtype: int64

# %%
# Tratar a renda ausente
df["renda"] = df["renda"].fillna(df["renda"].mean())
df.head()
# Out:
#    id     nome  idade     renda  divida estado_civil aprovado
# 0   1      Ana     25   3200.00    1200     solteiro      Sim
# 1   2    Bruno     42   8500.00    2500       casado      Sim
# 2   3    Carla     31  11868.75    4200     solteiro      Não
# 3   4   Daniel     19   1800.00     800     solteiro      Não
# 4   5  Eduarda    150   5000.00    1500       casado      Sim

# %%
# tratar valores invalidos
df.loc[df["idade"] > 90,"idade"] = df["idade"].mean().astype(int)
df.loc[df["divida"]< 0,"divida"] = df["divida"].mean()
df.head(10)
# Out:
#    id      nome      idade     renda       divida estado_civil aprovado
# 0   1       Ana  25.000000   3200.00  1200.000000     solteiro      Sim
# 1   2     Bruno  42.000000   8500.00  2500.000000       casado      Sim
# 2   3     Carla  31.000000  11868.75  4200.000000     solteiro      Não
# 3   4    Daniel  19.000000   1800.00   800.000000     solteiro      Não
# 4   5   Eduarda  41.647059   5000.00  1500.000000       casado      Sim
# 5   6    Felipe  37.000000   6200.00  2800.000000       casado      Sim
# 6   7  Gabriela  29.000000   4100.00  2335.294118     solteiro      Não
# 7   8  Henrique  48.000000  12000.00  3500.000000   divorciado      Sim
# 8   9   Isabela  34.000000   7200.00  2100.000000       casado      Sim
# 9  10      João  23.000000   2600.00  1800.000000     solteiro      Não

# %%
# remover os registros duplicados
print("Duplicados: ", df.duplicated().sum())
df = df.drop_duplicates().reset_index(drop=True)
df.head(20)
# Out:
# Duplicados:  1
#     id      nome      idade     renda       divida estado_civil aprovado
# 0    1       Ana  25.000000   3200.00  1200.000000     solteiro      Sim
# 1    2     Bruno  42.000000   8500.00  2500.000000       casado      Sim
# 2    3     Carla  31.000000  11868.75  4200.000000     solteiro      Não
# 3    4    Daniel  19.000000   1800.00   800.000000     solteiro      Não
# 4    5   Eduarda  41.647059   5000.00  1500.000000       casado      Sim
# 5    6    Felipe  37.000000   6200.00  2800.000000       casado      Sim
# 6    7  Gabriela  29.000000   4100.00  2335.294118     solteiro      Não
# 7    8  Henrique  48.000000  12000.00  3500.000000   divorciado      Sim
# 8    9   Isabela  34.000000   7200.00  2100.000000       casado      Sim
# 9   10      João  23.000000   2600.00  1800.000000     solteiro      Não
# 10  11     Karen  51.000000  95000.00  4000.000000       casado      Sim
# 11  12     Lucas  28.000000   3900.00  2400.000000     solteiro      Não
# ...

# %%
# criar uma nova informação: coluna com percentual de compromentimento da renda
df["comprometimento_renda"] = df["divida"] / df["renda"]
df[["renda", "divida","comprometimento_renda","aprovado","idade"]].head(10)
# Out:
#       renda       divida  comprometimento_renda aprovado      idade
# 0   3200.00  1200.000000               0.375000      Sim  25.000000
# 1   8500.00  2500.000000               0.294118      Sim  42.000000
# 2  11868.75  4200.000000               0.353870      Não  31.000000
# 3   1800.00   800.000000               0.444444      Não  19.000000
# 4   5000.00  1500.000000               0.300000      Sim  41.647059
# 5   6200.00  2800.000000               0.451613      Sim  37.000000
# 6   4100.00  2335.294118               0.569584      Não  29.000000
# 7  12000.00  3500.000000               0.291667      Sim  48.000000
# 8   7200.00  2100.000000               0.291667      Sim  34.000000
# 9   2600.00  1800.000000               0.692308      Não  23.000000
